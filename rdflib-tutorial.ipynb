# %% [markdown]
# # Knowledge Representation on the Web -- RDF tutorial
#
# In this tutorial we'll learn the basics of interacting with RDF graphs with Python. We'll be using rdflib for this, a widely used Ptyhon library for RDF (all documentation can be found [here](https://rdflib.readthedocs.io/en/stable/index.html))

# %% [markdown]
# 1. can not parse "https://csarven.ca/" -> add format="n3"
# 2. hadAge not in foaf namespace -> changed to foaf:age
# 3. Teacher not in foaf namespace -> changed to TEACH:Teacher, and added a section on adding a new namespace

# %% [markdown]
# ## Imports
# These are the main classes and types we'll be using from rdflib

# %%
import sys
# !{sys.executable} -m pip install rdflib

from rdflib import Graph, ConjunctiveGraph, Literal, BNode, Namespace, RDF, URIRef
from rdflib.namespace import DC, FOAF

import pprint
# Out:
# Requirement already satisfied: rdflib in /Users/lisestork/anaconda3/envs/krw/lib/python3.9/site-packages (5.0.0)
# Requirement already satisfied: pyparsing in /Users/lisestork/anaconda3/envs/krw/lib/python3.9/site-packages (from rdflib) (2.4.7)
# Requirement already satisfied: six in /Users/lisestork/anaconda3/envs/krw/lib/python3.9/site-packages (from rdflib) (1.15.0)
# Requirement already satisfied: isodate in /Users/lisestork/anaconda3/envs/krw/lib/python3.9/site-packages (from rdflib) (0.6.0)

# %% [markdown]
# ## Loading data remotely and from files
#
# rdflib accepts importing RDF data from a variety of sources, either locally from a file (including an extensive support of serializations), or remotely via a URI (this is a great way of checking practically if URIs return RDF according to the 3rd Linked Data principle).
#
# A Graph object is always required to load triples.
# **Note**: to load quads, and hence supporting named graphs, you'll need to use an instance of ConjunctiveGraph instead

# %%
g = Graph()
h = Graph()
result = g.parse("http://www.w3.org/People/Berners-Lee/card")

result2 = h.parse("https://csarven.ca/", format="n3")

print("Graph has %s statements." % len(g))
print("Graph has %s statements." % len(h))
# Out:
# Graph has 86 statements.
# Graph has 525 statements.

# %%
with open("demo.nt", "r") as f:
    print("This is an N-Triples file")
    print("=========================")
    for line in f:
        print(line)
    
with open("demo.xml", "r") as f:
    print("This is a RDF/XML file")
    print("======================")
    for line in f:
        print(line)
    
with open("demo.ttl", "r") as f:
    print("This is a Turtle file")
    print("=====================")
    for line in f:
        print(line)
# Out:
# This is an N-Triples file
# =========================
# <http://bigasterisk.com/foaf.rdf#drewp> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://xmlns.com/foaf/0.1/Person> .
#
# <http://bigasterisk.com/foaf.rdf#drewp> <http://example.com/says> "Hello world" .
#
# This is a RDF/XML file
# ======================
# <?xml version="1.0" encoding="UTF-8"?>
#
# <rdf:RDF
#
#    xmlns:ns1="http://example.com/"
#
#    xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#
# >
#
#   <rdf:Description rdf:about="http://bigasterisk.com/foaf.rdf#drewp">
#
#     <ns1:says>Hello world</ns1:says>
#
#     <rdf:type rdf:resource="http://xmlns.com/foaf/0.1/Person"/>
#
#   </rdf:Description>
#
# </rdf:RDF>
#
# This is a Turtle file
# =====================
# @prefix ns1: <http://example.com/> .
#
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
#
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
#
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
#
#
# <http://bigasterisk.com/foaf.rdf#drewp> a <http://xmlns.com/foaf/0.1/Person> ;
#
#     ns1:says "Hello world" .

# %%
g.serialize(destination='output.ttl', format='turtle')

# %%
g = Graph()
g.parse("demo.ttl", format='turtle')

len(g) # prints 2
# Out:
# 2

# %%
for stmt in g:
    pprint.pprint(stmt)
# Out:
# (rdflib.term.URIRef('http://bigasterisk.com/foaf.rdf#drewp'),
#  rdflib.term.URIRef('http://example.com/says'),
#  rdflib.term.Literal('Hello world'))
# (rdflib.term.URIRef('http://bigasterisk.com/foaf.rdf#drewp'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/Person'))

# %%
# You can also parse directly from a string
g = Graph()

g.parse(data = '<urn:a> <urn:p> <urn:b>.', format='n3')
for stmt in g:
    pprint.pprint(stmt)
# Out:
# (rdflib.term.URIRef('urn:a'),
#  rdflib.term.URIRef('urn:p'),
#  rdflib.term.URIRef('urn:b'))

# %% [markdown]
# ## Saving RDF graphs
#
# We use the function Graph.serialize(format)

# %%
g = Graph()
g.parse("demo.nt", format='n3')
# for a,b,c in g:
#     print(a,b,c)

print(g.serialize(format='nt').decode()) # 'html', 'hturtle', 'mdata', 'microdata', 'n3', 'nquads', 'nt', 'rdfa', 'rdfa1.0', 'rdfa1.1', 'trix', 'turtle', 'xml'
# Out:
# <http://bigasterisk.com/foaf.rdf#drewp> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://xmlns.com/foaf/0.1/Person> .
# <http://bigasterisk.com/foaf.rdf#drewp> <http://example.com/says> "Hello world" .

# %% [markdown]
# ##  Merging graphs
#
# Merging graphs can be done via sequential parsings or by the overloaded operator +
#
# **Note:** Set-theoretic graph semantics apply

# %%
graph = Graph()

# Sequential parsings merge *new* triples

graph.parse("demo.nt", format='nt')
graph.parse("demo.xml", format='xml')

print("Graph has {} triples".format(len(graph)))
# Out:
# Graph has 2 triples

# %%
g1 = Graph()
g1.parse("demo.nt", format='nt')
print("g1 has {} triples".format(len(g1)))

g2 = Graph()
g2.parse("demo.xml", format='xml')
print("g2 has {} triples".format(len(g2)))

graph = g1 + g2
print("g1 + g2 has {} triples".format(len(graph)))
# Out:
# g1 has 2 triples
# g2 has 2 triples
# g1 + g2 has 2 triples

# %%
# Now, if we merge graphs with different contents

tim_g = Graph()
tim_g.parse("http://www.w3.org/People/Berners-Lee/card")
print("Tim graph has {} triples".format(len(tim_g)))

g3 = g1 + tim_g
print("g3 has {} triples".format(len(g3)))
# Out:
# Tim graph has 86 triples
# g3 has 88 triples

# %% [markdown]
# ## Creating RDF triples
#
# Triples are added to the graph with the function Graph.add()
#
# The parameter is a triple given in a Python **tuple** (subject, predicate, object)
#
# Notice the namespace convenience syntax!

# %%
g = Graph()

# Create an identifier to use as the subject for Donna.
donna = BNode()
# donna = URIRef("http://example.org/donna")

# Add triples using store's add method.
g.add( (donna, RDF.type, FOAF.Person) )
g.add( (donna, FOAF.nick, Literal("donna", lang="foo")) )
g.add( (donna, FOAF.name, Literal("Donna Fales")) )
g.add( (donna, FOAF.mbox, URIRef("mailto:donna@example.org")) )

for i in range(100):
    g.add((donna, FOAF.age, Literal(i)))

print(len(g))

for s in g:
    pprint.pprint(s)
    print()
# Out:
# 104
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('25', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('66', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('51', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('95', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('93', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('85', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('10', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('58', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('92', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('89', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/name'),
#  rdflib.term.Literal('Donna Fales'))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('31', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('65', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('21', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('39', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('13', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('20', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('46', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('48', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('18', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('86', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('69', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('97', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('47', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('7', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('37', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('70', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('72', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('40', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('36', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/mbox'),
#  rdflib.term.URIRef('mailto:donna@example.org'))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('49', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('81', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('16', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('67', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('28', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('33', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('52', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('11', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('79', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('76', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('54', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('8', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('23', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('32', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('80', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('9', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('17', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('19', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('35', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('88', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('94', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('99', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('34', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/Person'))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('14', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/nick'),
#  rdflib.term.Literal('donna', lang='foo'))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('60', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('15', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('43', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('27', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('71', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('68', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('24', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('73', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('26', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('41', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('62', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('90', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('57', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('29', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('53', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('64', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('75', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('6', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('84', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('22', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('56', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('74', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('38', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('44', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('30', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('77', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('82', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('98', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('45', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('50', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('91', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('87', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('83', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('61', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('96', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('55', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('59', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('78', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('42', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('63', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#  rdflib.term.Literal('12', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))

# %%
for stmt in g:
    print(stmt)
# Out:
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('25', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('66', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('51', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('95', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('93', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('85', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('10', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('58', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('92', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('89', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/name'), rdflib.term.Literal('Donna Fales'))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('31', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('65', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('21', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('39', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('13', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('20', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('46', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('48', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('18', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('86', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('69', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('97', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('47', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('7', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('37', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('70', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('72', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('40', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('36', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/mbox'), rdflib.term.URIRef('mailto:donna@example.org'))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('49', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('81', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('16', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('67', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('28', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('33', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('52', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('11', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('79', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('76', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('54', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('8', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('23', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('32', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('80', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('9', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('17', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('19', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('35', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('88', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('94', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('99', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('34', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/Person'))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('14', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/nick'), rdflib.term.Literal('donna', lang='foo'))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('60', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('15', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('43', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('27', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('71', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('68', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('24', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('73', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('26', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('41', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('62', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('90', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('57', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('29', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('53', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('64', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('75', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('6', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('84', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('22', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('56', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('74', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('38', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('44', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('30', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('77', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('82', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('98', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('45', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('50', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('91', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('87', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('83', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('61', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('96', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('55', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('59', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('78', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('42', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('63', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na793f5c4a7114b81bb41f17862dbad11'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('12', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))

# %%
print(FOAF.Person)
# Out:
# http://xmlns.com/foaf/0.1/Person

# %%
print(FOAF.imadethisup)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/krw/lib/python3.9/site-packages/rdflib/namespace.py in __getattr__(self, name)
#     185             try:
# --> 186                 return self.term(name)
#     187             except KeyError as e:
#
# ~/anaconda3/envs/krw/lib/python3.9/site-packages/rdflib/namespace.py in term(self, name)
#     171         if uri is None:
# --> 172             raise KeyError(
#     173                 "term '{}' not in namespace '{}'".format(name, self.uri)
#
# KeyError: "term 'imadethisup' not in namespace 'http://xmlns.com/foaf/0.1/'"
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-a7ba085fad8d> in <module>
# ----> 1 print(FOAF.imadethisup)
#
# ~/anaconda3/envs/krw/lib/python3.9/site-packages/rdflib/namespace.py in __getattr__(self, name)
#     186                 return self.term(name)
#     187             except KeyError as e:
# --> 188                 raise AttributeError(e)
#     189
#     190     def __str__(self):
#
# AttributeError: "term 'imadethisup' not in namespace 'http://xmlns.com/foaf/0.1/'"

# %% [markdown]
# ## Namespaces
# The namespace module defines many common namespaces such as RDF, RDFS, OWL, FOAF, SKOS, etc., but you can also easily add URIs within a different namespace:

# %%
TEACH = Namespace("http://linkedscience.org/teach/ns#")
TEACH.Teacher
# Out:
# rdflib.term.URIRef('http://linkedscience.org/teach/ns#Teacher')

# %% [markdown]
# Check out the specification to see which other terms are used within the TEACH namespace. http://linkedscience.org/teach/ns/#sec-specification.
# You can use a NamespaceManager to bind a prefix to a namespace:

# %%
g.namespace_manager.bind('TEACH', URIRef('http://linkedscience.org/teach/ns#'))
TEACH.Teacher.n3(g.namespace_manager)
# Out:
# 'TEACH:Teacher'

# %%
KRW = Namespace("http://krw.vu.nl/data#")
KRW.Teacher
KRW.Student
# Out:
# rdflib.term.URIRef('http://krw.vu.nl/data#Student')

# %% [markdown]
# ## Navigating graphs
#
# rdflib uses iterators to navigate Graphs. The methods for navigating subjects, predicates and objects are Graph.subjects, Graph.predicates, Graph.objects

# %%
g = Graph()
g.parse("http://www.w3.org/People/Berners-Lee/card")

# Iterate over triples in store and print them out.
print("--- printing raw triples ---")
for s, p, o in g:
    print(p)
# Out:
# --- printing raw triples ---
# http://xmlns.com/foaf/0.1/member
# http://xmlns.com/foaf/0.1/maker
# http://www.w3.org/2000/10/swap/pim/contact#street
# http://rdfs.org/sioc/ns#avatar
# http://www.w3.org/2006/vcard/ns#street-address
# http://www.w3.org/2003/01/geo/wgs84_pos#lat
# http://xmlns.com/foaf/0.1/maker
# http://www.w3.org/2006/vcard/ns#hasAddress
# http://www.w3.org/ns/pim/space#preferencesFile
# http://xmlns.com/foaf/0.1/account
# http://xmlns.com/foaf/0.1/maker
# http://xmlns.com/foaf/0.1/account
# http://www.w3.org/2000/10/swap/pim/contact#homePage
# http://www.w3.org/2003/01/geo/wgs84_pos#long
# http://www.w3.org/ns/solid/terms#profileHighlightColor
# http://xmlns.com/foaf/0.1/based_near
# http://usefulinc.com/ns/doap#developer
# http://www.w3.org/2000/10/swap/pim/contact#country
# http://xmlns.com/foaf/0.1/maker
# http://schema.org/owns
# http://purl.org/dc/elements/1.1/title
# http://usefulinc.com/ns/doap#developer
# http://xmlns.com/foaf/0.1/title
# http://xmlns.com/foaf/0.1/workplaceHomepage
# http://xmlns.com/foaf/0.1/mbox_sha1sum
# http://www.w3.org/2000/01/rdf-schema#label
# http://creativecommons.org/ns#license
# http://www.w3.org/2003/01/geo/wgs84_pos#lat
# http://xmlns.com/foaf/0.1/givenname
# http://purl.org/dc/elements/1.1/title
# http://xmlns.com/foaf/0.1/mbox
# http://www.w3.org/2006/vcard/ns#locality
# http://www.w3.org/ns/ldp#inbox
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://xmlns.com/foaf/0.1/maker
# http://www.w3.org/ns/auth/cert#modulus
# http://www.w3.org/ns/pim/space#storage
# http://xmlns.com/foaf/0.1/primaryTopic
# http://www.w3.org/2000/01/rdf-schema#seeAlso
# http://www.w3.org/2003/01/geo/wgs84_pos#location
# http://www.w3.org/ns/pim/space#storage
# http://www.w3.org/ns/pim/space#storage
# http://www.w3.org/2000/10/swap/pim/contact#participant
# http://www.w3.org/2006/vcard/ns#postal-code
# http://www.w3.org/ns/auth/cert#key
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://purl.org/dc/elements/1.1/title
# http://www.w3.org/2000/10/swap/pim/contact#street2
# http://www.w3.org/2000/10/swap/pim/contact#publicHomePage
# http://www.w3.org/2000/10/swap/pim/contact#office
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/ns/solid/terms#editableProfile
# http://www.w3.org/2006/vcard/ns#region
# http://xmlns.com/foaf/0.1/weblog
# http://www.w3.org/2000/10/swap/pim/contact#participant
# http://xmlns.com/foaf/0.1/name
# http://xmlns.com/foaf/0.1/openid
# http://xmlns.com/foaf/0.1/homepage
# http://www.w3.org/ns/solid/terms#oidcIssuer
# http://www.w3.org/ns/auth/cert#exponent
# http://xmlns.com/foaf/0.1/nick
# http://www.w3.org/2000/10/swap/pim/contact#address
# http://xmlns.com/foaf/0.1/nick
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://xmlns.com/foaf/0.1/primaryTopic
# http://purl.org/dc/elements/1.1/title
# http://www.w3.org/2000/10/swap/pim/contact#assistant
# http://www.w3.org/2000/10/swap/pim/contact#postalCode
# http://xmlns.com/foaf/0.1/maker
# http://www.w3.org/ns/solid/terms#profileBackgroundColor
# http://www.w3.org/2000/01/rdf-schema#label
# http://xmlns.com/foaf/0.1/account
# http://www.w3.org/2003/01/geo/wgs84_pos#long
# http://xmlns.com/foaf/0.1/family_name
# http://xmlns.com/foaf/0.1/member
# http://creativecommons.org/ns#license
# http://www.w3.org/2006/vcard/ns#fn
# http://www.w3.org/ns/solid/terms#publicTypeIndex
# http://www.w3.org/2000/01/rdf-schema#seeAlso
# http://www.w3.org/2000/10/swap/pim/contact#preferredURI
# http://purl.org/dc/elements/1.1/title
# http://www.w3.org/2000/10/swap/pim/contact#city
# http://purl.org/dc/terms/title
# http://xmlns.com/foaf/0.1/img

# %%
# Printing subjects, predicates and objects out of the tuple omits Python datatypes
print("--- printing raw triples ---")
for s, p, o in g:
    print(s, p, o)
# Out:
# --- printing raw triples ---
# http://dig.csail.mit.edu/data#DIG http://xmlns.com/foaf/0.1/member https://www.w3.org/People/Berners-Lee/card#i
# http://www.w3.org/People/Berners-Lee/card http://xmlns.com/foaf/0.1/maker https://www.w3.org/People/Berners-Lee/card#i
# N4b04e4b796334726b2e922d66e6ee606 http://www.w3.org/2000/10/swap/pim/contact#street 32 Vassar Street
# https://www.w3.org/People/Berners-Lee/card#i http://rdfs.org/sioc/ns#avatar http://www.w3.org/People/Berners-Lee/images/timbl-image-by-Coz-cropped.jpg
# N95834223ae17482ab5740e011402d730 http://www.w3.org/2006/vcard/ns#street-address 32 Vassar Street
# Nd45e1b87c3d8472bb648d16c784acab7 http://www.w3.org/2003/01/geo/wgs84_pos#lat 42.361860
# http://dig.csail.mit.edu/2007/01/camp/data#course http://xmlns.com/foaf/0.1/maker https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2006/vcard/ns#hasAddress N95834223ae17482ab5740e011402d730
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/pim/space#preferencesFile https://timbl.com/timbl/Data/preferences.n3
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/account http://en.wikipedia.org/wiki/User:Timbl
# http://www.w3.org/DesignIssues/Overview.html http://xmlns.com/foaf/0.1/maker https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/account http://twitter.com/timberners_lee
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/10/swap/pim/contact#homePage http://www.w3.org/People/Berners-Lee/
# Nd45e1b87c3d8472bb648d16c784acab7 http://www.w3.org/2003/01/geo/wgs84_pos#long -71.091840
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/solid/terms#profileHighlightColor #00467E
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/based_near N6ceec019e95f403dbc4d4dfb326ef18e
# http://dig.csail.mit.edu/2005/ajar/ajaw/data#Tabulator http://usefulinc.com/ns/doap#developer https://www.w3.org/People/Berners-Lee/card#i
# N4b04e4b796334726b2e922d66e6ee606 http://www.w3.org/2000/10/swap/pim/contact#country USA
# http://www.w3.org/2011/Talks/0331-hyderabad-tbl/data#talk http://xmlns.com/foaf/0.1/maker https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i http://schema.org/owns https://timblbot.inrupt.net/profile/card#me
# http://www.w3.org/People/Berners-Lee/card http://purl.org/dc/elements/1.1/title Tim Berners-Lee's FOAF file
# http://www.w3.org/2000/10/swap/data#Cwm http://usefulinc.com/ns/doap#developer https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/title Sir
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/workplaceHomepage https://www.w3.org/
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/mbox_sha1sum 965c47c5a70db7407210cef6e4e6f5374a525c5c
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/01/rdf-schema#label Tim Berners-Lee
# https://timbl.com/timbl/Public/friends.ttl http://creativecommons.org/ns#license http://creativecommons.org/licenses/by-nc/3.0/
# N6ceec019e95f403dbc4d4dfb326ef18e http://www.w3.org/2003/01/geo/wgs84_pos#lat 42.361860
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/givenname Timothy
# http://dig.csail.mit.edu/breadcrumbs/blog/4 http://purl.org/dc/elements/1.1/title timbl's blog on DIG
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/mbox mailto:timbl@w3.org
# N95834223ae17482ab5740e011402d730 http://www.w3.org/2006/vcard/ns#locality Cambridge
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/ldp#inbox https://timbl.com/timbl/Public/Inbox
# http://www.w3.org/People/Berners-Lee/card http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://xmlns.com/foaf/0.1/PersonalProfileDocument
# https://timbl.com/timbl/Public/friends.ttl http://xmlns.com/foaf/0.1/maker https://www.w3.org/People/Berners-Lee/card#i
# Nc5783431fb194065a9513839466470af http://www.w3.org/ns/auth/cert#modulus ...
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/pim/space#storage https://timbl.solid.community/
# http://www.w3.org/People/Berners-Lee/card http://xmlns.com/foaf/0.1/primaryTopic https://www.w3.org/People/Berners-Lee/card#i
# http://dig.csail.mit.edu/breadcrumbs/blog/4 http://www.w3.org/2000/01/rdf-schema#seeAlso http://dig.csail.mit.edu/breadcrumbs/blog/feed/4
# Na10e0b34580343138a6e390ba319a952 http://www.w3.org/2003/01/geo/wgs84_pos#location Nd45e1b87c3d8472bb648d16c784acab7
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/pim/space#storage https://timbl.com/timbl/Public/
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/pim/space#storage https://timbl.inrupt.net/
# http://wiki.ontoworld.org/index.php/_IRW2006 http://www.w3.org/2000/10/swap/pim/contact#participant https://www.w3.org/People/Berners-Lee/card#i
# N95834223ae17482ab5740e011402d730 http://www.w3.org/2006/vcard/ns#postal-code 02139
# http://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/auth/cert#key Nc5783431fb194065a9513839466470af
# Nc5783431fb194065a9513839466470af http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/ns/auth/cert#RSAPublicKey
# https://timbl.com/timbl/Public/friends.ttl http://purl.org/dc/elements/1.1/title Tim Berners-Lee's editable profile
# N4b04e4b796334726b2e922d66e6ee606 http://www.w3.org/2000/10/swap/pim/contact#street2 MIT CSAIL Building 32
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/10/swap/pim/contact#publicHomePage http://www.w3.org/People/Berners-Lee/
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/10/swap/pim/contact#office Na10e0b34580343138a6e390ba319a952
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/10/swap/pim/contact#Male
# N95834223ae17482ab5740e011402d730 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2006/vcard/ns#Work
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/solid/terms#editableProfile https://timbl.com/timbl/Public/friends.ttl
# N95834223ae17482ab5740e011402d730 http://www.w3.org/2006/vcard/ns#region MA
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/weblog http://dig.csail.mit.edu/breadcrumbs/blog/4
# http://www.ecs.soton.ac.uk/~dt2/dlstuff/www2006_data#panel-panelk01 http://www.w3.org/2000/10/swap/pim/contact#participant https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/name Timothy Berners-Lee
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/openid https://www.w3.org/People/Berners-Lee/
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/homepage https://www.w3.org/People/Berners-Lee/
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/solid/terms#oidcIssuer https://timbl.com
# Nc5783431fb194065a9513839466470af http://www.w3.org/ns/auth/cert#exponent 65537
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/nick TimBL
# Na10e0b34580343138a6e390ba319a952 http://www.w3.org/2000/10/swap/pim/contact#address N4b04e4b796334726b2e922d66e6ee606
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/nick timbl
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://xmlns.com/foaf/0.1/Person
# https://timbl.com/timbl/Public/friends.ttl http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://xmlns.com/foaf/0.1/PersonalProfileDocument
# https://timbl.com/timbl/Public/friends.ttl http://xmlns.com/foaf/0.1/primaryTopic https://www.w3.org/People/Berners-Lee/card#i
# http://www.w3.org/DesignIssues/Overview.html http://purl.org/dc/elements/1.1/title Design Issues for the World Wide Web
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/10/swap/pim/contact#assistant https://www.w3.org/People/Berners-Lee/card#amy
# N4b04e4b796334726b2e922d66e6ee606 http://www.w3.org/2000/10/swap/pim/contact#postalCode 02139
# http://dig.csail.mit.edu/breadcrumbs/blog/4 http://xmlns.com/foaf/0.1/maker https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/solid/terms#profileBackgroundColor #ffffff
# http://www.ecs.soton.ac.uk/~dt2/dlstuff/www2006_data#panel-panelk01 http://www.w3.org/2000/01/rdf-schema#label The Next Wave of the Web (Plenary Panel)
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/account http://www.reddit.com/user/timbl/
# N6ceec019e95f403dbc4d4dfb326ef18e http://www.w3.org/2003/01/geo/wgs84_pos#long -71.091840
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/family_name Berners-Lee
# http://www.w3.org/data#W3C http://xmlns.com/foaf/0.1/member https://www.w3.org/People/Berners-Lee/card#i
# http://www.w3.org/People/Berners-Lee/card http://creativecommons.org/ns#license http://creativecommons.org/licenses/by-nc/3.0/
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2006/vcard/ns#fn Tim Berners-Lee
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/solid/terms#publicTypeIndex https://timbl.com/timbl/Public/PublicTypeIndex.ttl
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/01/rdf-schema#seeAlso https://timbl.com/timbl/Public/friends.ttl
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/10/swap/pim/contact#preferredURI https://www.w3.org/People/Berners-Lee/card#i
# http://wiki.ontoworld.org/index.php/_IRW2006 http://purl.org/dc/elements/1.1/title Identity, Reference and the Web workshop 2006
# N4b04e4b796334726b2e922d66e6ee606 http://www.w3.org/2000/10/swap/pim/contact#city Cambridge
# http://www.w3.org/2011/Talks/0331-hyderabad-tbl/data#talk http://purl.org/dc/terms/title Designing the Web for an Open Society
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/img https://www.w3.org/Press/Stock/Berners-Lee/2001-europaeum-eighth.jpg

# %%
print("PRINTING SUBJECTS")
for s in g.subjects():
    print(s)
# Out:
# PRINTING SUBJECTS
# http://dig.csail.mit.edu/data#DIG
# http://www.w3.org/People/Berners-Lee/card
# N4b04e4b796334726b2e922d66e6ee606
# https://www.w3.org/People/Berners-Lee/card#i
# N95834223ae17482ab5740e011402d730
# Nd45e1b87c3d8472bb648d16c784acab7
# http://dig.csail.mit.edu/2007/01/camp/data#course
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# http://www.w3.org/DesignIssues/Overview.html
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# Nd45e1b87c3d8472bb648d16c784acab7
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# http://dig.csail.mit.edu/2005/ajar/ajaw/data#Tabulator
# N4b04e4b796334726b2e922d66e6ee606
# http://www.w3.org/2011/Talks/0331-hyderabad-tbl/data#talk
# https://www.w3.org/People/Berners-Lee/card#i
# http://www.w3.org/People/Berners-Lee/card
# http://www.w3.org/2000/10/swap/data#Cwm
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# https://timbl.com/timbl/Public/friends.ttl
# N6ceec019e95f403dbc4d4dfb326ef18e
# https://www.w3.org/People/Berners-Lee/card#i
# http://dig.csail.mit.edu/breadcrumbs/blog/4
# https://www.w3.org/People/Berners-Lee/card#i
# N95834223ae17482ab5740e011402d730
# https://www.w3.org/People/Berners-Lee/card#i
# http://www.w3.org/People/Berners-Lee/card
# https://timbl.com/timbl/Public/friends.ttl
# Nc5783431fb194065a9513839466470af
# https://www.w3.org/People/Berners-Lee/card#i
# http://www.w3.org/People/Berners-Lee/card
# http://dig.csail.mit.edu/breadcrumbs/blog/4
# Na10e0b34580343138a6e390ba319a952
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# http://wiki.ontoworld.org/index.php/_IRW2006
# N95834223ae17482ab5740e011402d730
# http://www.w3.org/People/Berners-Lee/card#i
# Nc5783431fb194065a9513839466470af
# https://timbl.com/timbl/Public/friends.ttl
# N4b04e4b796334726b2e922d66e6ee606
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# N95834223ae17482ab5740e011402d730
# https://www.w3.org/People/Berners-Lee/card#i
# N95834223ae17482ab5740e011402d730
# https://www.w3.org/People/Berners-Lee/card#i
# http://www.ecs.soton.ac.uk/~dt2/dlstuff/www2006_data#panel-panelk01
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# Nc5783431fb194065a9513839466470af
# https://www.w3.org/People/Berners-Lee/card#i
# Na10e0b34580343138a6e390ba319a952
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# https://timbl.com/timbl/Public/friends.ttl
# https://timbl.com/timbl/Public/friends.ttl
# http://www.w3.org/DesignIssues/Overview.html
# https://www.w3.org/People/Berners-Lee/card#i
# N4b04e4b796334726b2e922d66e6ee606
# http://dig.csail.mit.edu/breadcrumbs/blog/4
# https://www.w3.org/People/Berners-Lee/card#i
# http://www.ecs.soton.ac.uk/~dt2/dlstuff/www2006_data#panel-panelk01
# https://www.w3.org/People/Berners-Lee/card#i
# N6ceec019e95f403dbc4d4dfb326ef18e
# https://www.w3.org/People/Berners-Lee/card#i
# http://www.w3.org/data#W3C
# http://www.w3.org/People/Berners-Lee/card
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# http://wiki.ontoworld.org/index.php/_IRW2006
# N4b04e4b796334726b2e922d66e6ee606
# http://www.w3.org/2011/Talks/0331-hyderabad-tbl/data#talk
# https://www.w3.org/People/Berners-Lee/card#i

# %%
print("PRINTING PREDICATES")
for p in g.predicates():
    if len(p) > 13:
        print(p)
# Out:
# PRINTING PREDICATES
# http://xmlns.com/foaf/0.1/member
# http://xmlns.com/foaf/0.1/maker
# http://www.w3.org/2000/10/swap/pim/contact#street
# http://rdfs.org/sioc/ns#avatar
# http://www.w3.org/2006/vcard/ns#street-address
# http://www.w3.org/2003/01/geo/wgs84_pos#lat
# http://xmlns.com/foaf/0.1/maker
# http://www.w3.org/2006/vcard/ns#hasAddress
# http://www.w3.org/ns/pim/space#preferencesFile
# http://xmlns.com/foaf/0.1/account
# http://xmlns.com/foaf/0.1/maker
# http://xmlns.com/foaf/0.1/account
# http://www.w3.org/2000/10/swap/pim/contact#homePage
# http://www.w3.org/2003/01/geo/wgs84_pos#long
# http://www.w3.org/ns/solid/terms#profileHighlightColor
# http://xmlns.com/foaf/0.1/based_near
# http://usefulinc.com/ns/doap#developer
# http://www.w3.org/2000/10/swap/pim/contact#country
# http://xmlns.com/foaf/0.1/maker
# http://schema.org/owns
# http://purl.org/dc/elements/1.1/title
# http://usefulinc.com/ns/doap#developer
# http://xmlns.com/foaf/0.1/title
# http://xmlns.com/foaf/0.1/workplaceHomepage
# http://xmlns.com/foaf/0.1/mbox_sha1sum
# http://www.w3.org/2000/01/rdf-schema#label
# http://creativecommons.org/ns#license
# http://www.w3.org/2003/01/geo/wgs84_pos#lat
# http://xmlns.com/foaf/0.1/givenname
# http://purl.org/dc/elements/1.1/title
# http://xmlns.com/foaf/0.1/mbox
# http://www.w3.org/2006/vcard/ns#locality
# http://www.w3.org/ns/ldp#inbox
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://xmlns.com/foaf/0.1/maker
# http://www.w3.org/ns/auth/cert#modulus
# http://www.w3.org/ns/pim/space#storage
# http://xmlns.com/foaf/0.1/primaryTopic
# http://www.w3.org/2000/01/rdf-schema#seeAlso
# http://www.w3.org/2003/01/geo/wgs84_pos#location
# http://www.w3.org/ns/pim/space#storage
# http://www.w3.org/ns/pim/space#storage
# http://www.w3.org/2000/10/swap/pim/contact#participant
# http://www.w3.org/2006/vcard/ns#postal-code
# http://www.w3.org/ns/auth/cert#key
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://purl.org/dc/elements/1.1/title
# http://www.w3.org/2000/10/swap/pim/contact#street2
# http://www.w3.org/2000/10/swap/pim/contact#publicHomePage
# http://www.w3.org/2000/10/swap/pim/contact#office
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/ns/solid/terms#editableProfile
# http://www.w3.org/2006/vcard/ns#region
# http://xmlns.com/foaf/0.1/weblog
# http://www.w3.org/2000/10/swap/pim/contact#participant
# http://xmlns.com/foaf/0.1/name
# http://xmlns.com/foaf/0.1/openid
# http://xmlns.com/foaf/0.1/homepage
# http://www.w3.org/ns/solid/terms#oidcIssuer
# http://www.w3.org/ns/auth/cert#exponent
# http://xmlns.com/foaf/0.1/nick
# http://www.w3.org/2000/10/swap/pim/contact#address
# http://xmlns.com/foaf/0.1/nick
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://xmlns.com/foaf/0.1/primaryTopic
# http://purl.org/dc/elements/1.1/title
# http://www.w3.org/2000/10/swap/pim/contact#assistant
# http://www.w3.org/2000/10/swap/pim/contact#postalCode
# http://xmlns.com/foaf/0.1/maker
# http://www.w3.org/ns/solid/terms#profileBackgroundColor
# http://www.w3.org/2000/01/rdf-schema#label
# http://xmlns.com/foaf/0.1/account
# http://www.w3.org/2003/01/geo/wgs84_pos#long
# http://xmlns.com/foaf/0.1/family_name
# http://xmlns.com/foaf/0.1/member
# http://creativecommons.org/ns#license
# http://www.w3.org/2006/vcard/ns#fn
# http://www.w3.org/ns/solid/terms#publicTypeIndex
# http://www.w3.org/2000/01/rdf-schema#seeAlso
# http://www.w3.org/2000/10/swap/pim/contact#preferredURI
# http://purl.org/dc/elements/1.1/title
# http://www.w3.org/2000/10/swap/pim/contact#city
# http://purl.org/dc/terms/title
# http://xmlns.com/foaf/0.1/img

# %%
print("PRINTING OBJECTS")
for o in g.objects():
    print(o)

# %% [markdown]
# We can also filter the subjects, predicates and objects we want to retrieve, and match their values like in a database "join" operation

# %%
g = Graph()

# Create an identifier to use as the subject for Donna.
donna = URIRef('urn:donna')
ila = URIRef('urn:ila')
# Add triples using store's add method.
g.add( (donna, RDF.type, FOAF.Person) )
g.add( (ila, RDF.type, FOAF.Person) )
g.add( (ila, RDF.type, TEACH.Teacher) )
g.add( (donna, FOAF.nick, Literal("donna", lang="foo")) )
g.add( (donna, FOAF.name, Literal("Donna Fales")) )
g.add( (donna, FOAF.mbox, URIRef("mailto:donna@example.org")) )
g.add( (ila, FOAF.mbox, URIRef("mailto:ila@example.org")) )

# For each foaf:Person in the store print out its mbox property.
# print("--- printing mboxes ---")
# for person in g.subjects(RDF.type, FOAF.Person):
#     for mbox in g.objects(person, FOAF.mbox):
#         print(mbox)

# You can reuse matches of subjects to filter further e.g. objects
for entity in g.subjects(RDF.type, None):
    print(entity)
    for objects in g.objects(entity, RDF.type):
        print(objects)

# %% [markdown]
# ### Basic triple matching (almost querying!)
#
# We use method Graph.triples and a Python tuple that acts as a mask for specifying our criteria

# %%
g = Graph()
g.parse("http://www.w3.org/People/Berners-Lee/card")

tim = URIRef("https://www.w3.org/People/Berners-Lee/card#i")

if ( tim, RDF.type, FOAF.Person ) in g:
   print("This graph knows that Tim is a person!")

if ( tim, None, None ) in g:
    print("This graph contains triples about Tim!")

# %%
for s,p,o in g.triples( (None, None, None) ):
    print(s,p,o)

# %%
for s,p,o in g.triples( (tim, RDF.type, None) ):
    print(s,p,o)

# %% [markdown]
# ## Namespaces and bindings

# %%
mid_uri = URIRef("http://purl.org/midi-ld/midi#")
mid = Namespace(mid_uri)

print(mid['hello'])  # as item - for things that are not valid python identifiers
print(mid.hello)     # as attribute

# %%
g = Graph()

# Create an identifier to use as the subject for Donna.
donna = BNode()

# Add triples using store's add method.
g.add( (donna, RDF.type, FOAF.Person) )
g.add( (donna, FOAF.nick, Literal("donna", lang="foo")) )
g.add( (donna, FOAF.name, Literal("Donna Fales")) )
g.add( (donna, FOAF.mbox, URIRef("mailto:donna@example.org")) )

print(g.serialize(format='turtle').decode())

# %%
foaf_uri = URIRef("http://xmlns.com/foaf/0.1/")
foaf_namespace = Namespace(foaf_uri)

g = Graph()

# Bind a few prefix, namespace pairs for more readable output
g.bind("foaf", foaf_namespace)

# Create an identifier to use as the subject for Donna.
donna = BNode()

# Add triples using store's add method.
g.add( (donna, RDF.type, FOAF.Person) )
g.add( (donna, FOAF.nick, Literal("donna", lang="foo")) )
g.add( (donna, FOAF.name, Literal("Donna Fales")) )
g.add( (donna, FOAF.mbox, URIRef("mailto:donna@example.org")) )

print(g.serialize(format='turtle').decode())
